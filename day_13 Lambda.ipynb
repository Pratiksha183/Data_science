# %% [markdown]
# ## lAMBDA FUNCTIONS
# - write in single line
# - when we wanted a quick code
# - for the quick
# - Commonly used with functions like map(), filter(), and sorted().
# - Helps keep code concise and readable.
# What is a Lambda Function?
# - A lambda function is a small, anonymous function in Python.
# It is defined using the keyword lambda instead of def.
# Unlike normal functions, a lambda function has no name and is usually used for short, simple operations.
#
#
# ## Syntax:
#
# arguments: Input values (like parameters in a normal function).
# expression: A single statement that is evaluated and returned.
# lambda arguments: expression

# %% [markdown]
# ## Key Characteristics
# Anonymous: No function name is required.
# Single Expression: Can only contain one expression (no multiple statements).
# Inline Use: Often used where functions are needed temporarily.

# %%
def add(a, b ):
    return a + b

# %%
add(90,10)
# Out:
# 100

# %%
lambda a,b : a+b
# Out:
# <function __main__.<lambda>(a, b)>

# %%
#calling

add = lambda a,b : a+b

# %%
add(4,5)
# Out:
# 9

# %%
mul = lambda a,b : a*b

# %%
mul(4,5)
# Out:
# 20

# %%
# using def

def greet():
    return "hellow world!"

greet()
# Out:
# 'hellow world!'

# %%
greet = lambda :("hello world!")

# %%
greet()
# Out:
# 'hello world!'

# %%
# using def
def square(x):
    return x*x

square(5)
# Out:
# 25

# %%
# write a function to square the element

square = lambda a : a*a

# %%
square(9)
# Out:
# 81

# %%
def num_check(num):
 if num % 2 == 0:
  print("even")
 else :

    print("odd")

# %%
num_check(8)
# Out:
# even

# %%
num_check = lambda num : "even " if num % 2 == 0 else "odd"

# %%
num_check(10)
# Out:
# 'even '

# %%
voting_check = lambda age : "you can apply" if age >= 18 else "sorry , u can't vote"

# %%
voting_check(18)
# Out:
# 'you can apply'

# %%
voting_check(1)
# Out:
# "sorry , u can't vote"

# %%
convert_capital = lambda x : x.lower()

# %%
convert_capital("HELLOW")
# Out:
# 'hellow'

# %%
convert_small= lambda x : x.upper()
convert_small("hi pratiksha have a grat day ahead ")
# Out:
# 'HI PRATIKSHA HAVE A GRAT DAY AHEAD '

# %%
empty = lambda x : "string empty" if x == "" else "not empty"

# %%
empty("")
# Out:
# 'string empty'

# %%
empty(20)
# Out:
# 'not empty'

# %%
check_num = lambda num : "positive" if num>= 0 else "negative"

# %%
check_num(2)
# Out:
# 'positive'

# %%
check_num(-2)
# Out:
# 'negative'
