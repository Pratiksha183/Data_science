# %% [markdown]
# # function in python
#
# -keyword used = def()
# - A function in Python is a reusable block of code that performs a specific task

# %%
print("hellow world")
# Out:
# hellow world

# %%
# addition of 2 elements traditinal way

a= 10
b = 12
total = a+b
print(total)
# Out:
# 22

# %%
# syntax of function

def function_name(parameters):

- def → Keyword to define a function.
- function_name → Identifier used to call the function.
- parameters → Inputs passed into the function.
-nreturn → Sends output back to the caller

# %%
def greet():
    print("good morning")

# %%
greet()              # calling without parameters
# Out:
# good morning

# %%
# calling with parameters

def greet(student_name):
    print("good morning have a nice day",student_name)

# %%
greet("rock")
# Out:
# good morning have a nice day rock

# %%
# function for addition of 2 element

def add(a,b):
    print(a+b)

# %%
add(10,20)
# Out:
# 30
# value of a is  10
# value of a is  20

# %%
# add 3 nos
def add_of_three(a,b,c):
    print(a+b+c)

# %%
add_of_three(10,20,30)
# Out:
# 60

# %%
# for multiplying 3 element

def multiply(a,b,c):         # created function for multiplication
    print(a*b*c)

# %%
multiply (2,2,2)
# Out:
# 8

# %%
# i want to save result into variable how to do ?


def add(a,b):
    print(a+b)

    result = add(10,20)

# %%
add(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 add(result)
#
# NameError: name 'result' is not defined

# %%
def add(a,b):
    return(a+b)

# %%
result = add(20,10)

# %%
print(result)
# Out:
# 30

# %%
# write a function for 2 element and store in result

def divide(x,y):
    return(x/y)

# %%
ans = divide(100,50)     # STORING data in ans

# %%
print(ans)
# Out:
# 2.0

# %%
# write a function for odd and even

def check_num(num):

    if num %2 == 0:
        return "even"
    else:
        return "odd"

# %%
check_num(9)
# Out:
# 'odd'

# %%
check_num(10)
# Out:
# 'even'

# %%
# print percentage
marks = [66,77,88,99,100]

# %%
def percentage(marks):
    return sum(marks)/len(marks)

# %%
percentage(marks)
# Out:
# 86.0

# %%
cart =26,80,56,156
 # calculate average of cart

# %%
def avg(cart):
    return sum(cart)/len(cart)

avg(cart)
# Out:
# 79.5

# %%
# if user pass empty list we cant divide by 0 it will throw error to solve add condition

# %%
cart = []

# %%
def blinkit_bill(cart):
    if len(cart) == 0 :
         return "add values in cart "
    return sum(cart)/len(cart)

# %%
blinkit_bill(cart)
# Out:
# 'add values in cart '

# %%
cart.append("strawberry")
cart.append("banana")
cart.append("oats")

# %%
cart
# Out:
# ['strawberry', 'banana', 'oats']

# %%
cart = [] 
len(cart)
# Out:
# 0

# %%
def blinkit_bill(cart):

    if len(cart) == 0:
        return "Add values in cart"
    return sum(cart) / len(cart)

# %%
blinkit_bill(cart)
# Out:
# 'Add values in cart'

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # solve this
# # write any function for list to append -3 -4
# # write function to sort the list
# # write a function to check if  data contains duplicate or not (set doesn't take duplcate)
#
# # [1,2,3,4] - True
# #[1,2,3,4,4] - False         interview question google ,oracle

# %%
# write any function for list to append -3 -4
list=[]

def append_no(list):
     list.append("-4")
     list.append("-3")
     return list
append_no(list)
# Out:
# ['-4', '-3']

# %%
# write function to sort the list
def sort_list(values):
    return sorted(values)

numbers = [6, 5, 8, 9 ,100,1,45,80]

sort_list(numbers)
# Out:
# [1, 5, 6, 8, 9, 45, 80, 100]

# %%
# write a function to check if  data contains duplicate or not (set doesn't take duplcate)

# [1,2,3,4] - True no duplicates
#[1,2,3,4,4] - False have duplicates       
#  interview question google ,oracle


def check_duplicates(data):
    return len(data) == len(set(data))


print(check_duplicates([1, 2, 3,4]))

print(check_duplicates([1, 2, 4, 4]))
# Out:
# True
# False

# %%
check_duplicates([1, 2, 3, 4, 4])
# Out:
# False

# %% [markdown]
# # practice

# %%
def square(x):
    return x * x

# %%
square(5)
# Out:
# 25

# %%
def add(a,b):
    return a+b

# %%
add(4,5)
# Out:
# 9

# %% [markdown]
# f- string in python

# %%
name = "Alice"
age = 22

# The f-string automatically fills in the variables
message = f"Hello, my name is {name} and I am {age} years old."
print(message)
# Out:
# Hello, my name is Alice and I am 22 years old.

# %%
city = "pune"
temp = 29
print("today's weather in" ,city, "is",temp )
print(f"Today's weather in {city} is {temp}")
# Out:
# today's weather in pune is 29
# Today's weather in pune is 29

# %%
print(f"{city} {temp}")
# Out:
# pune 29

# %%
city = "pune"
temp = 29
weather = "rainy"
time = 8

# %%
print(f"The city is {city} and the temprature is {temp}, as the weather is {weather} so go out at {time}")
# Out:
# The city is pune and the temprature is 29, as the weather is rainy so go out at 8
