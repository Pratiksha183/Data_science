# %% [markdown]
# # Type casting - Implict and Explicit
# # Implicit - automatically convert
# # Explicit - manual conversion

# %%
# Implicit
a=10
b=3
c=a/b
print(c)

# Explicit
y=50
e=float(y)
print(e,type(e))

a="60"
# Out:
# 3.3333333333333335
# 50.0 <class 'float'>

# %%
age = 10 #int
name = "raj" #string
rain = False  #bool
distance = 1.0 # float

# %%
print(age)
print(name)
# Out:
# 10
# raj

# %%
#type casting (changed string to int by int(a)a 
a = '10'
b = '20'
a= int(a)
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#variable call
city = "pune"
print("pune is in maharashtra",city)
# Out:
# pune is in maharashtra pune

# %%
# create a variable with int and convert it in float

a = 12
print(type(a))
a = float(a)
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# typecastin# TYPECASTING

# %%
#create a variable with float and convert it in int

b = 10.6
print(type(b))
b = int(b)
print(type(b))
print(b)
# Out:
# <class 'float'>
# <class 'int'>
# 10

# %%
num_str = "12.75"
print (type(num_str))

num_float = float(num_str)
print (type(num_float))

num_int = int(num_float)
print (type(num_int))


print(num_str)      # 12.75
print(num_float)    # 12.75
print(num_int)      # 12
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# 12.75
# 12.75
# 12

# %%
print (type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>

# %%
name = "alice"
city = "pune"
hobbies = ["reading","painting","travelling","gaming", "watching movies"]
sports  =["cricket" , "football"]
print(hobbies)
hobbies [2:-2]
hobbies [0:4]
hobbies [0]
# Out:
# ['reading', 'painting', 'travelling', 'gaming', 'watching movies']
# 'reading'

# %%
# for multiple lines execution use 3 quoates """"

lyric = "I can’t provide the full lyrics to  by Alan Walker, but I can summarize the song or discuss its meaningIf this night is not forever
At least we are together
I know I'm not alone
I know I'm not alone
Anywhere, whenever
Apart, but still together
I know I'm not alone
I know I'm not alone"
# Out:
#   Cell In[33], line 1
#     lyric = "I can’t provide the full lyrics to  by Alan Walker, but I can summarize the song or discuss its meaningIf this night is not forever
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
lyric = """I can’t provide the full lyrics to  by Alan Walker, but I can summarize the song or discuss its meaningIf this night is not forever
At least we are together
I know I'm not alone
I know I'm not alone
Anywhere, whenever
Apart, but still together
I know I'm not alone
I know I'm not alone"""

# %%
print(lyric)
# Out:
# I can’t provide the full lyrics to  by Alan Walker, but I can summarize the song or discuss its meaningIf this night is not forever
# At least we are together
# I know I'm not alone
# I know I'm not alone
# Anywhere, whenever
# Apart, but still together
# I know I'm not alone
# I know I'm not alone

# %% [markdown]
# # list indexing
# Indexing
# Every item in a list has a position number called an index. Indexing allows us to access a single item from the list using its position.
#
# Positive indexing starts from 0 for the first item, 1 for the second item, and so on.
# Negative indexing starts from -1 for the last item, -2 for the second last item, and so on. Negative indexing is useful when we want to access items from the end of the list without knowing its exact length.
# Slicing

# %%
cities = ["pune" , "banglore","nagpur","kochin", "latur","kolhapur"]
cities
cities [ 0 : 5]
# Out:
# ['pune', 'banglore', 'nagpur', 'kochin', 'latur']

# %%
# indexing starts from 0 
# from ending it from -1

cities [0]
cities[0 : -1]
cities[3: -2]

#iwant last city 
cities[-1]

#i want blr and latur add +1 element
cities[4]
# Out:
# 'latur'

# %% [markdown]
# # Slicing
# Slicing allows us to access a range or a portion of the list instead of a single item. The general syntax is:
#
# list_name[start : stop : step]

# %%
print('Slice from index 1 to 3 :', cities[1:4])

# i want pune to latur  add index +1
print('Slice from index 1 to 3 :',cities[0:5])


cities[0:5]
# Out:
# Slice from index 1 to 3 : ['banglore', 'nagpur', 'kochin']
# Slice from index 1 to 3 : ['pune', 'banglore', 'nagpur', 'kochin', 'latur']
# ['pune', 'banglore', 'nagpur', 'kochin', 'latur']

# %% [markdown]
# # tuple Method there are 2 methods
# #1.count()
# #2.index()

# %%
numbers = (1, 2, 3, 2, 4, 2)
print(numbers.count(2))


print(numbers.index(1))
# Out:
# 3
# 0

# %%
#list
items = ["rain", "window" , 4 , 1.5 ,"false"]

# %%
# string to int
x = "25"
print(type(x))
y = int(x)
print(y)   # 25
print(type(y))
# Out:
# <class 'str'>
# 25
# <class 'int'>
