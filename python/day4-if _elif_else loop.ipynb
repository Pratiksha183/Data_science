# %% [markdown]
# if else loop
# if elif loop

# %%
age = int(input("enter number"))  
    # to take input from user usr input()

if age >=21 :
      print("you can vote")
else :
      print("you are not eligible")
# Out:
# you can vote

# %%
age = int(input("enter your age :"))


if age >=18 :
      print("you are applicable for voting")
else :
      print("you are not applicable for voting")
# Out:
# you are not applicable for voting

# %%
marks = int(input("enter your age :"))


if marks >= 50 :
      print("you are pass")
else :
      print("you are fail")
# Out:
# you are pass

# %%
username = 'pratiksha'
password = 123

u = input("enter username :")
p = int(input("enter the password :"))

if u == username and p == password :
    print ("login successful")
else :
    print("login failed ")
# Out:
# login failed

# %%
# take input values from user and perform addition

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
add = a + b
print("Sum:", add)
# Out:
# Sum: 8

# %%
n = int(input("enter no between 1 to 10"))

if n<=10:
 print("you chose coorrect no")
else: 
 print("something went wrong")
# Out:
# something went wrong

# %%
value = int(input("print value between 1 to 3"))

if value == 1:
    print('study')
elif value == 2:
    print('take rest')
else:
    print("watch movie")
# Out:
# take rest

# %%
signal = input("Enter signal color (red/green/yellow): ")

if signal == "red": 
    print("Stop")
elif signal == "yellow":
    print("Wait")
else:
    print("Go")
# Out:
# Go

# %%
# rainfall: umbrella pick or not pick

rain = input("Enter rain (yes/no): ")


if rain == "yes":
    print("Pick umbrella")
else:
    print("Don't pick umbrella")
# Out:
# Don't pick umbrella

# %%
# fever check

temprature = float(input("Enter temperature: "))

if temprature >= 35:
    print("You have fever")
else:
    print("You are fine")
# Out:
# You have fever

# %%
day = input()
if day=="weekday":
     print("work/study")
else:
    print("movie day")
# Out:
# movie day

# %%
#elif

day = int(input())

if day == 1:
    print("monday")

elif day == 2:
     print("tuesday")

elif day == 3:
     print("wednsday")     

elif day == 4:
     print("thursday")  

elif day == 5:
     print("friday")   

elif day == 6:
     print("saturday")

elif day == 7:
     print("sunday")

else :
     print("print valid day")
# Out:
# tuesday

# %%
#if : always
#elif : as per requirnment
#else : as per requirnment

# %%
print( "********** MINI CALCULATOR ***********"  )

no1 = int(input( print("enter the first no :", no1)))
no2 = int(input(print("enter the second no :", no2)))
op  = input(" enter the operator =,-,/,*")

if op == '+' :
   print ("the addition is :" , no1 + no2)
elif op =="-" :
 print("the subtreaction is :" , no1 - no2)
elif op =="/" :
  print("the multiplication is :" , no1*no2)
elif op =="/" :
  print("the divison is :" , no1/no2)

else:
  print("put correct operator")
# Out:
# ********** MINI CALCULATOR ***********
# enter the first no : 56
# enter the second no : 8
# the addition is : 16

# %%
#Ask the user to enter a number and print whether it is even or odd.

number = int(input( "enter the number"))

if number % 2 == 0 :
        print("even")
else :
        print("odd")
# Out:
# even

# %%
#Write a program to check if a character is:
#vowel → a, e, i, o, u
#else → consonant

character = input("Enter an alphabet: ")

if character in ("a", "e", "i", "o", "u"):
    print("Vowel")
else:
    print("Consonant")
# Out:
# Consonant

# %%
#Ask the user for temperature and print:
#temp >= 40 → Very hot
#temp >= 30 → Hot
#temp >= 20 → Normal
#else → Cold"""


temperature =  int(input("Enter value"))

if temperature >= 40:
    print("very hot")
elif temperature >= 30:
    print("hot")
elif temperature >= 20:
    print("normal")
else:
    print("cold")
# Out:
# very hot

# %%
marks = int(input ("enter your marks"))

if marks >= 90:
    print("Grade: A")
elif marks >= 80:
    print("Grade: B")
elif marks >= 70:
    print("Grade: C")
else:
    print("Grade: D")
# Out:
# Grade: D
