# %%
variable = is a container which stores the data

# %%
name = "pratiksha"
city = "Latur"
weather = "its a rainy day"

# %% [markdown]
# variable = name  ,
# integer = number  ,
# float = 18.0

# %%
print(name)
print(city)
print (weather)
# Out:
# pratiksha
# Latur
# its a rainy day

# %% [markdown]
# is operator :  comapares location of 2 variable data if it is same returns true

# %%
x = 31
y = 36

print("location of x is :",id(x))
print("location of y is :",id(y))

x is y
# Out:
# location of x is : 140711732410088
# location of y is : 140711732410248
# False

# %%
x = 31
y = 31

print("location of x is :",id(x))
print("location of y is :",id(y))

x is y
# Out:
# location of x is : 140711732410088
# location of y is : 140711732410088
# True

# %%
# list [] (mutable (you can change, add, or remove items.)
# tuple () immutable (you cannot change its items after creation.)

friends =[ "alice","bob","charlie"]
print (type(friends))
print(friends)
friends[0:-1]
friends[1]
print(type(friends))
# Out:
# <class 'list'>
# ['alice', 'bob', 'charlie']
# <class 'list'>

# %%
fruits=["mango","apple" , 2.1]
print(type(2.1))
print(type(fruits))
# Out:
# <class 'float'>
# <class 'list'>

# %%
#how to create varible

-type of variable = string,int,float,boolen

-type() : to check type of data int,boolen,string

# %% [markdown]
# difference between list and tuple ?
#
# -tuple use bracket(_)     eg. a=("rock","pen")     #IMMUTABLE
#
# -list use []              eg.  a =["rock,"pen"]    #MUTTABLE
