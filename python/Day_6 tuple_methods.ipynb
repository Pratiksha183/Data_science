# %% [markdown]
# # tuple :A tuple is an ordered collection of elements in Python

# %% [markdown]
# git pull origin main

# %% [markdown]
#  same in tuple n list
#  order n indexing , duplicates,count

# %%
a = [1,2,3,4 ,4]

a.count(4)
print(type(a))


a.append("412")

b = ("8830982176")

a.extend(b)


a
# Out:
# <class 'list'>
# [1, 2, 3, 4, 4, '412', '8', '8', '3', '0', '9', '8', '2', '1', '7', '6']

# %%
a.count(4)
# Out:
# 2

# %%
a.index(3)
# Out:
# 2

# %%
a.count(4)

# %%
shop =("blinkit","zepto","instamart")
shop

shop[1]
# Out:
# 'zepto'

# %% [markdown]
# #tuples
# -are immutable , once created can't edited
# -ordered
# -allow duplicates
#
# Ordered: The items in a tuple have a defined order, and that order will not change
#
# - Immutable: Once created, the elements of a tuple cannot be modified.
# - Allow Duplicates: Tuples can contain duplicate values.
# - Indexed: Tuple items are indexed, with the first item having index [0].
# - Heterogeneous: A tuple can store elements of different data types
# (integers, strings,   floats, lists, etc.).

# %%
shop =("zomato","zepto","instamart")
shop
# Out:
# ('zomato', 'zepto', 'instamart')

# %%
a = ("ajay","radha","priya","ajay")
a
a[0]
# Out:
# 'ajay'

# %%
#Tuples = Tuples are widely used in 
 # store fixed data like
- coordinates
-bank account
- blood 
-marks
-accuracy


A tuple can be created in several ways:

Using parentheses: my_tuple = (1, 2, 3)

Without parentheses (tuple packing): my_tuple = 1, 2, 3

Using the tuple() constructor: my_tuple = tuple([1, 2, 3])

A single-element tuple requires a trailing comma: my_tuple = (5,)

# %%
tuple=[1,2,3,4]
tuple
# Out:
# [1, 2, 3, 4]

# %%
tuple=1,2,3,4
tuple
# Out:
# (1, 2, 3, 4)

# %%
fruits=("mango","jackfruit")
print("i like",fruits)
# Out:
# i like ('mango', 'jackfruit')

# %%
fruits=("mango","jackfruit")
print("i like",fruits[0])
# Out:
# i like mango

# %%
colours =("red","black","orange")
print("i like ", colours[0],"colour")
# Out:
# i like  red colour

# %%
colours[2]
# Out:
# 'orange'

# %%
# Tuple methods

1.count()
2.index()

# %%
party = ("pizza","burger","cola","chips","tacco","chips","chips")
party
# Out:
# ('pizza', 'burger', 'cola', 'chips', 'tacco', 'chips', 'chips')

# %%
party.index("tacco")
# Out:
# 4

# %%
party.count("cola")
# Out:
# 1

# %%
party.count("chips")
# Out:
# 3

# %%
# make a list of student name and marka and update one students mark

students = [["raj", 80],  ["sheela", 90],  ["sohel", 45],["reeva", 30]]

students.append(["meena", 75])
students[1][1] = 70

students
# Out:
# [['raj', 80], ['sheela', 70], ['sohel', 45], ['reeva', 30], ['meena', 75]]
