# %%
# Data Types in Python

A **data type** defines the kind of value a variable can hold.  
Python has several built-in data types that help us work with different kinds of information.

---

## Common Data Types

- **Numeric Types**
  - `int` → whole numbers (e.g., `10`, `-5`)
  - `float` → decimal numbers (e.g., `3.14`, `-0.5`)
  - `complex` → numbers with real and imaginary parts (e.g., `2 + 3j`)

- **Sequence Types**
  - `str` → text (e.g., `"Hello"`)
  - `list` → ordered, changeable collection (e.g., `[1, 2, 3]`)
  - `tuple` → ordered, unchangeable collection (e.g., `(1, 2, 3)`)

- **Mapping Type**
  - `dict` → key-value pairs (e.g., `{"name": "Pradip", "age": 25}`)

- **Set Types**
  - `set` → unordered collection of unique items (e.g., `{1, 2, 3}`)
  - `frozenset` → immutable version of a set

- **Boolean Type**
  - `bool` → logical values `True` or `False`

---

## Example

```python
age = 25          # int
pi = 3.14         # float
name = "Pradip"   # str
marks = [85, 90]  # list
point = (2, 3)    # tuple
student = {"id": 1, "name": "Pradip"}  # dict
unique = {1, 2, 3} # set
is_active = True   # bool

# %%
name = "pratiksha"
city = "Latur"
weather = "its a rainy day"

# %% [markdown]
# variable = name  ,
# integer = number  ,
# float = 18.0

# %%
print(name)
print(city)
print (weather)
# Out:
# pratiksha
# Latur
# its a rainy day

# %% [markdown]
# location and
# is operator = compares location of 2 variables nd if both same returns true

# %%
x=10
y=10

print('x location is :', id(x))
print('y location is -', id(y))
# Out:
# x location is : 140704605631560
# y location is - 140704605631560

# %%
print( x is y)
# Out:
# True

# %%
x=10
y=30

print('x location is :', id(x))
print('y location is -', id(y))

print( x is y)
# Out:
# x location is : 140704605631560
# y location is - 140704605632200
# False

# %%
# list [] (mutable (you can change, add, or remove items.)
# tuple () immutable (you cannot change its items after creation.)

friends =[ "alice","bob","charlie"]
print (type(friends))
print(friends)
friends[0:-1]
friends[1]
print(type(friends))
# Out:
# <class 'list'>
# ['alice', 'bob', 'charlie']
# <class 'list'>

# %%
fruits=["mango","apple" , 2.1]
print(type(2.1))
print(type(fruits))
# Out:
# <class 'float'>
# <class 'list'>

# %%
#how to create varible

-type of variable = string,int,float,boolen,complex

-type() : to check type of data int,boolen,string

# %% [markdown]
# difference between list and tuple ?
#
#
#
# -tuple use bracket(_)     eg. a=("rock","pen")     #IMMUTABLE
#
# -list use []              eg.  a =["rock,"pen"]    #MUTTABLE

# %%
Convert the integer 10 into a float.
x = 10
type (x)
x = float(x)
type(y)
# Out:
# float

# %%
Convert the integer 10 into a float.
a = 10
type(a)

a='10'
type(a)
# Out:
# str

# %%
# it won't perform addition because both r strings ,so it simply concat both nos.

number = "10"

print(number +"5")
# Out:
# 105

# %%
print( "My name is pratiksha and I am 22 years old")
# Out:
# My name is pratiksha and I am 22 years old
